# %% [markdown]
# # Analysis and Findings

# %%
import pandas as pd
import os

# %%
os.chdir('../')

# %%
path_to_processed_data="2. Processed data/"

# %%
final_df=pd.read_csv(path_to_processed_data+"Final_combined_output_485272_ADBS.csv",index_col=None,low_memory=False)

# %%
final_df[["INSTNM","AWLEVEL","distance (in miles)"]]
# Out:
#                                      INSTNM  AWLEVEL  distance (in miles)
# 0                          Barry University        5            10.379378
# 1                           Broward College        3            24.868305
# 2                           Broward College        5            24.868305
# 3         Concorde Career Institute-Miramar        3            12.013463
# 4          Florida International University        5             4.034913
# 5              Florida Career College-Miami        3             3.944969
# 6           Keiser University-Ft Lauderdale        3            28.320117
# 7           Keiser University-Ft Lauderdale        5            28.320117
# 8                        Miami Dade College        3            10.016906
# 9                        Miami Dade College        5            10.016906
# 10                      University of Miami        5             7.524966
# 11             Nova Southeastern University        5            19.676945
# ...

# %%
final_df["Rank"] = final_df["CTOTALT_2018"].rank(ascending=False) 
# final_df[["CTOTALT_2018"]]

# %% [markdown]
# ## Highest number of completions for the most recent year
#
# ## Awards/degrees conferred across all race/ethnicities and both genders

# %%
final_df[["INSTNM","Rank","CTOTALT_2018"]].sort_values(by="Rank")
# Out:
#                                      INSTNM  Rank  CTOTALT_2018
# 6           Keiser University-Ft Lauderdale   1.0         559.0
# 8                        Miami Dade College   2.0         531.0
# 11             Nova Southeastern University   3.0         411.0
# 23                Miami Regional University   4.0         381.0
# 4          Florida International University   5.0         348.0
# 1                           Broward College   6.0         296.0
# 9                        Miami Dade College   7.0         282.0
# 22                            SABER College   8.0         181.0
# 10                      University of Miami   9.0         174.0
# 29              West Coast University-Miami  10.0         130.0
# 15  Florida National University-Main Campus  11.0         122.0
# 2                           Broward College  12.0         117.0
# 7           Keiser University-Ft Lauderdale  13.0         110.0
# 3         Concorde Career Institute-Miramar  14.0          76.0
# ...

# %% [markdown]
# ## Average Completion for the Last 5 years

# %%
final_df['Avg_completion_5yrs'] = final_df[['CTOTALT_2018', 'CTOTALT_2017','CTOTALT_2016','CTOTALT_2015','CTOTALT_2014']].mean(axis=1)

# %% [markdown]
# T1

# %%
Table_last=final_df[["INSTNM","AWLEVEL","LATITUDE","LONGITUD","distance (in miles)",'CTOTALT_2018', 'CTOTALT_2017','CTOTALT_2016','CTOTALT_2015','CTOTALT_2014',"Avg_completion_5yrs"]].sort_values(by="Avg_completion_5yrs",ascending=False)
Table_last
# Out:
#                                      INSTNM  AWLEVEL   LATITUDE   LONGITUD  \
# 8                        Miami Dade College        3  25.777717 -80.190856
# 6           Keiser University-Ft Lauderdale        3  26.185869 -80.163959
# 11             Nova Southeastern University        5  26.079337 -80.242480
# 1                           Broward College        3  26.119422 -80.141830
# 4          Florida International University        5  25.757320 -80.373928
# 9                        Miami Dade College        5  25.777717 -80.190856
# 23                Miami Regional University        3  25.810667 -80.267007
# 10                      University of Miami        5  25.721260 -80.278662
# 22                            SABER College        3  25.771518 -80.261299
# 0                          Barry University        5  25.878908 -80.198925
# 2                           Broward College        5  26.119422 -80.141830
# ...

# %% [markdown]
# ## Retention Rate  (Rank based on Recent year Student faculty Ratio)

# %%
# final_df["Rank"] = final_df["CTOTALT_2018"].rank(ascending=False) 
final_df['Rank_Stdentfacult']=final_df["STUFACR _2017"].rank(ascending=False)

# %% [markdown]
# T2 (No need rank)

# %%
Table_last=Table_last.merge(final_df[["INSTNM","STUFACR _2017","AWLEVEL"]],how="left",on=["INSTNM","AWLEVEL"])

# %%
Table_last
# Out:
#                                      INSTNM  AWLEVEL   LATITUDE   LONGITUD  \
# 0                        Miami Dade College        3  25.777717 -80.190856
# 1           Keiser University-Ft Lauderdale        3  26.185869 -80.163959
# 2              Nova Southeastern University        5  26.079337 -80.242480
# 3                           Broward College        3  26.119422 -80.141830
# 4          Florida International University        5  25.757320 -80.373928
# 5                        Miami Dade College        5  25.777717 -80.190856
# 6                 Miami Regional University        3  25.810667 -80.267007
# 7                       University of Miami        5  25.721260 -80.278662
# 8                             SABER College        3  25.771518 -80.261299
# 9                          Barry University        5  25.878908 -80.198925
# 10                          Broward College        5  26.119422 -80.141830
# ...

# %% [markdown]
# ### Full-time cohort includes full-time first-time degree/certificate seeking students enrolled at the institution in the fall of the prior year (including those enrolled for the first time the preceding summer term and those whose intent was not known upon entry to the institution).

# %%
final_df['Rank_retention']=final_df["RRFTCT_2017"].rank(ascending=False)

# %%
final_df[["INSTNM","RRFTCT_2017","Rank_retention"]].sort_values(by="Rank_retention")
# Out:
#                                      INSTNM  RRFTCT_2017  Rank_retention
# 4          Florida International University       4159.0             1.0
# 10                      University of Miami       2042.0             2.0
# 6           Keiser University-Ft Lauderdale        972.0             3.5
# 7           Keiser University-Ft Lauderdale        972.0             3.5
# 11             Nova Southeastern University        647.0             5.0
# 0                          Barry University        479.0             6.0
# 31  Florida Career College-Lauderdale Lakes        248.0             7.0
# 12                     St Thomas University        193.0             8.0
# 30                   Florida Career College        170.0             9.0
# 22                            SABER College        150.0            10.0
# 3         Concorde Career Institute-Miramar        143.0            11.0
# 5              Florida Career College-Miami        117.0            12.0
# ...

# %%
final_df[["INSTNM","GRCOHRT_2017"]]
# Out:
#                                      INSTNM  GRCOHRT_2017
# 0                          Barry University         604.0
# 1                           Broward College        3298.0
# 2                           Broward College        3298.0
# 3         Concorde Career Institute-Miramar           NaN
# 4          Florida International University        3489.0
# 5              Florida Career College-Miami           NaN
# 6           Keiser University-Ft Lauderdale        4097.0
# 7           Keiser University-Ft Lauderdale        4097.0
# 8                        Miami Dade College        8783.0
# 9                        Miami Dade College        8783.0
# 10                      University of Miami        2185.0
# 11             Nova Southeastern University         976.0
# 12                     St Thomas University         229.0
# 13             City College-Fort Lauderdale          14.0
# 14  Florida National University-Main Campus         472.0
# ...

# %% [markdown]
# ## 12- month erollment Grand total (12-month unduplicated headcount)

# %%
final_df[["EFYTOTLT_2018","EFYTOTLT_2017","EFYTOTLT_2016","EFYTOTLT_2015","EFYTOTLT_2014"]]
# Out:
#     EFYTOTLT_2018  EFYTOTLT_2017  EFYTOTLT_2016  EFYTOTLT_2015  EFYTOTLT_2014
# 0          3935.0         4191.0         4403.0         4722.0         5076.0
# 1         60896.0        62013.0        63024.0        63389.0        62508.0
# 2         60896.0        62013.0        63024.0        63389.0        62508.0
# 3           951.0          930.0          855.0          868.0          926.0
# 4         58244.0        55835.0        55100.0        55173.0        53525.0
# 5           824.0          644.0          483.0          556.0         9902.0
# 6         31911.0        31711.0        32937.0        31000.0        32135.0
# 7         31911.0        31711.0        32937.0        31000.0        32135.0
# 8         88475.0        88312.0        91749.0        95821.0        97341.0
# 9         88475.0        88312.0        91749.0        95821.0        97341.0
# 10        11984.0        12002.0        12243.0        12432.0        12325.0
# ...

# %%
final_df['Avg_12mEnroll_5yrs'] = final_df[["EFYTOTLT_2018","EFYTOTLT_2017","EFYTOTLT_2016","EFYTOTLT_2015","EFYTOTLT_2014"]].mean(axis=1)

# %% [markdown]
# T3

# %%
final_df[["INSTNM","EFYTOTLT_2018","EFYTOTLT_2017","EFYTOTLT_2016","EFYTOTLT_2015","EFYTOTLT_2014","Avg_12mEnroll_5yrs"]].sort_values(by="Avg_12mEnroll_5yrs",ascending=False)
# Out:
#                                      INSTNM  EFYTOTLT_2018  EFYTOTLT_2017  \
# 8                        Miami Dade College        88475.0        88312.0
# 9                        Miami Dade College        88475.0        88312.0
# 2                           Broward College        60896.0        62013.0
# 1                           Broward College        60896.0        62013.0
# 4          Florida International University        58244.0        55835.0
# 6           Keiser University-Ft Lauderdale        31911.0        31711.0
# 7           Keiser University-Ft Lauderdale        31911.0        31711.0
# 10                      University of Miami        11984.0        12002.0
# 14  Florida National University-Main Campus         6909.0         6914.0
# 15  Florida National University-Main Campus         6909.0         6914.0
# 11             Nova Southeastern University         5026.0         4840.0
# 0                          Barry University         3935.0         4191.0
# ...

# %%
Table_last=Table_last.merge(final_df[["INSTNM","AWLEVEL","EFYTOTLT_2018","EFYTOTLT_2017","EFYTOTLT_2016","EFYTOTLT_2015","EFYTOTLT_2014","Avg_12mEnroll_5yrs"]],on=["INSTNM","AWLEVEL"])

# %%
Table_last
# Out:
#                                      INSTNM  AWLEVEL   LATITUDE   LONGITUD  \
# 0                        Miami Dade College        3  25.777717 -80.190856
# 1           Keiser University-Ft Lauderdale        3  26.185869 -80.163959
# 2              Nova Southeastern University        5  26.079337 -80.242480
# 3                           Broward College        3  26.119422 -80.141830
# 4          Florida International University        5  25.757320 -80.373928
# 5                        Miami Dade College        5  25.777717 -80.190856
# 6                 Miami Regional University        3  25.810667 -80.267007
# 7                       University of Miami        5  25.721260 -80.278662
# 8                             SABER College        3  25.771518 -80.261299
# 9                          Barry University        5  25.878908 -80.198925
# 10                          Broward College        5  26.119422 -80.141830
# ...

# %% [markdown]
# ## (12-month instructional activity) 12-month instructional activity credit hours: undergraduates

# %%
final_df[["CDACTUA_2017","CDACTUA_2016","CDACTUA_2015","CDACTUA_2014"]]
# Out:
#     CDACTUA_2017  CDACTUA_2016  CDACTUA_2015  CDACTUA_2014
# 0        99332.0      104196.0      112054.0      118131.0
# 1       878728.0      895229.0      894803.0      911117.0
# 2       878728.0      895229.0      894803.0      911117.0
# 3         6018.0        7308.0        6337.0        6616.0
# 4      1117621.0     1095364.0     1087712.0     1069136.0
# 5        15456.0       11592.0       13344.0      292031.0
# 6       793224.0      607862.0      614007.0      624170.0
# 7       793224.0      607862.0      614007.0      624170.0
# 8      1330518.0     1439563.0     1508894.0     1544273.0
# 9      1330518.0     1439563.0     1508894.0     1544273.0
# 10      321135.0      328181.0      330625.0      324191.0
# 11      119598.0      122951.0      125567.0      130967.0
# 12       45314.0       26641.0       40649.0       46310.0
# 13       17247.0       19516.0       22190.0       24907.0
# 14      153798.0      128958.0      119172.0      123162.0
# ...

# %%
final_df['Avg_12mEnrollInst_5yrs'] = final_df[["CDACTUA_2018","CDACTUA_2017","CDACTUA_2016","CDACTUA_2015","CDACTUA_2014"]].mean(axis=1)

# %% [markdown]
# T4

# %%
final_df[["INSTNM","CDACTUA_2017","CDACTUA_2017","CDACTUA_2016","CDACTUA_2015","CDACTUA_2014","Avg_12mEnrollInst_5yrs"]].sort_values(by="Avg_12mEnrollInst_5yrs",ascending=False)
# Out:
#                                      INSTNM  CDACTUA_2017  CDACTUA_2017  \
# 8                        Miami Dade College     1330518.0     1330518.0
# 9                        Miami Dade College     1330518.0     1330518.0
# 4          Florida International University     1117621.0     1117621.0
# 2                           Broward College      878728.0      878728.0
# 1                           Broward College      878728.0      878728.0
# 6           Keiser University-Ft Lauderdale      793224.0      793224.0
# 7           Keiser University-Ft Lauderdale      793224.0      793224.0
# 10                      University of Miami      321135.0      321135.0
# 14  Florida National University-Main Campus      153798.0      153798.0
# 15  Florida National University-Main Campus      153798.0      153798.0
# 11             Nova Southeastern University      119598.0      119598.0
# 0                          Barry University       99332.0       99332.0
# ...

# %%
Table_last=Table_last.merge(final_df[["INSTNM","AWLEVEL","CDACTUA_2017","CDACTUA_2017","CDACTUA_2016","CDACTUA_2015","CDACTUA_2014","Avg_12mEnrollInst_5yrs"]],on=["INSTNM","AWLEVEL"])

# %%
Table_last
# Out:
#                                      INSTNM  AWLEVEL   LATITUDE   LONGITUD  \
# 0                        Miami Dade College        3  25.777717 -80.190856
# 1           Keiser University-Ft Lauderdale        3  26.185869 -80.163959
# 2              Nova Southeastern University        5  26.079337 -80.242480
# 3                           Broward College        3  26.119422 -80.141830
# 4          Florida International University        5  25.757320 -80.373928
# 5                        Miami Dade College        5  25.777717 -80.190856
# 6                 Miami Regional University        3  25.810667 -80.267007
# 7                       University of Miami        5  25.721260 -80.278662
# 8                             SABER College        3  25.771518 -80.261299
# 9                          Barry University        5  25.878908 -80.198925
# 10                          Broward College        5  26.119422 -80.141830
# ...

# %% [markdown]
# ## Reported full-time equivalent (FTE) undergraduate enrollment, 2017-18

# %%
final_df[["FTEUG_2018","FTEUG_2017","FTEUG_2016","FTEUG_2015","FTEUG_2014"]]
# Out:
#     FTEUG_2018  FTEUG_2017  FTEUG_2016  FTEUG_2015  FTEUG_2014
# 0       3148.0      3311.0      3473.0      3735.0      3938.0
# 1      28912.0     29764.0     30311.0     30345.0     30835.0
# 2      28912.0     29764.0     30311.0     30345.0     30835.0
# 3        419.0       368.0       455.0       406.0       480.0
# 4      38534.0     37254.0     36512.0     36257.0     35638.0
# 5        659.0       515.0       386.0       445.0      9869.0
# 6      26475.0     26441.0     20262.0     20467.0     20806.0
# 7      26475.0     26441.0     20262.0     20467.0     20806.0
# 8      46554.0     45399.0     48705.0     51075.0     52309.0
# 9      46554.0     45399.0     48705.0     51075.0     52309.0
# 10     10747.0     10705.0     10939.0     11021.0     10806.0
# 11      4136.0      3987.0      4098.0      4186.0      4366.0
# 12      1560.0      1510.0       888.0      1355.0      1544.0
# 13       329.0       383.0       434.0       493.0       553.0
# ...

# %%
final_df['Avg_12mEnrollfte_5yrs'] = final_df[["FTEUG_2018","FTEUG_2017","FTEUG_2016","FTEUG_2015","FTEUG_2014"]].mean(axis=1)

# %% [markdown]
# T4

# %%
final_df[["INSTNM","FTEUG_2018","FTEUG_2017","FTEUG_2016","FTEUG_2015","FTEUG_2014","Avg_12mEnrollfte_5yrs"]].sort_values(by="Avg_12mEnrollfte_5yrs",ascending=False)
# Out:
#                                      INSTNM  FTEUG_2018  FTEUG_2017  \
# 8                        Miami Dade College     46554.0     45399.0
# 9                        Miami Dade College     46554.0     45399.0
# 4          Florida International University     38534.0     37254.0
# 2                           Broward College     28912.0     29764.0
# 1                           Broward College     28912.0     29764.0
# 6           Keiser University-Ft Lauderdale     26475.0     26441.0
# 7           Keiser University-Ft Lauderdale     26475.0     26441.0
# 10                      University of Miami     10747.0     10705.0
# 14  Florida National University-Main Campus      5125.0      5127.0
# 15  Florida National University-Main Campus      5125.0      5127.0
# 11             Nova Southeastern University      4136.0      3987.0
# 0                          Barry University      3148.0      3311.0
# 5              Florida Career College-Miami       659.0       515.0
# ...

# %%
Table_last=Table_last.merge(final_df[["INSTNM","AWLEVEL","FTEUG_2018","FTEUG_2017","FTEUG_2016","FTEUG_2015","FTEUG_2014","Avg_12mEnrollfte_5yrs"]],on=["INSTNM","AWLEVEL"])

# %%
Table_last
# Out:
#                                      INSTNM  AWLEVEL   LATITUDE   LONGITUD  \
# 0                        Miami Dade College        3  25.777717 -80.190856
# 1           Keiser University-Ft Lauderdale        3  26.185869 -80.163959
# 2              Nova Southeastern University        5  26.079337 -80.242480
# 3                           Broward College        3  26.119422 -80.141830
# 4          Florida International University        5  25.757320 -80.373928
# 5                        Miami Dade College        5  25.777717 -80.190856
# 6                 Miami Regional University        3  25.810667 -80.267007
# 7                       University of Miami        5  25.721260 -80.278662
# 8                             SABER College        3  25.771518 -80.261299
# 9                          Barry University        5  25.878908 -80.198925
# 10                          Broward College        5  26.119422 -80.141830
# ...

# %% [markdown]
# ## Fall Enrollment Grand total

# %%
final_df[["EFTOTLT_2017","EFTOTLT_2016","EFTOTLT_2015","EFTOTLT_2014","EFTOTLT_2013"]]
# Out:
#     EFTOTLT_2017  EFTOTLT_2016  EFTOTLT_2015  EFTOTLT_2014  EFTOTLT_2013
# 0         3505.0        3541.0        3776.0        3996.0        4341.0
# 1        40754.0       43700.0       43078.0       44119.0       43883.0
# 2        40754.0       43700.0       43078.0       44119.0       43883.0
# 3          528.0         551.0         467.0         640.0         508.0
# 4        47629.0       45856.0       41032.0       41009.0       39142.0
# 5          502.0         340.0         278.0        6227.0        5818.0
# 6        18630.0       18172.0       15310.0       18101.0       16039.0
# 7        18630.0       18172.0       15310.0       18101.0       16039.0
# 8        56001.0       55206.0       62332.0       66046.0       66298.0
# 9        56001.0       55206.0       62332.0       66046.0       66298.0
# 10       10832.0       10792.0       11060.0       11175.0       11380.0
# 11        4497.0        4295.0        4641.0        4699.0        5156.0
# ...

# %%
final_df['Avg_FallEnroll_efatotal_5yrs'] = final_df[["EFTOTLT_2017","EFTOTLT_2016","EFTOTLT_2015","EFTOTLT_2014","EFTOTLT_2013"]].mean(axis=1)

# %% [markdown]
# T5

# %%
final_df[["INSTNM","EFTOTLT_2017","EFTOTLT_2016","EFTOTLT_2015","EFTOTLT_2014","EFTOTLT_2013","Avg_FallEnroll_efatotal_5yrs"]].sort_values(by="Avg_FallEnroll_efatotal_5yrs",ascending=False)
# Out:
#                                      INSTNM  EFTOTLT_2017  EFTOTLT_2016  \
# 8                        Miami Dade College       56001.0       55206.0
# 9                        Miami Dade College       56001.0       55206.0
# 2                           Broward College       40754.0       43700.0
# 1                           Broward College       40754.0       43700.0
# 4          Florida International University       47629.0       45856.0
# 6           Keiser University-Ft Lauderdale       18630.0       18172.0
# 7           Keiser University-Ft Lauderdale       18630.0       18172.0
# 10                      University of Miami       10832.0       10792.0
# 11             Nova Southeastern University        4497.0        4295.0
# 0                          Barry University        3505.0        3541.0
# 15  Florida National University-Main Campus        4023.0        3191.0
# 14  Florida National University-Main Campus        4023.0        3191.0
# ...

# %%
Table_last=Table_last.merge(final_df[["INSTNM","AWLEVEL","EFTOTLT_2017","EFTOTLT_2016","EFTOTLT_2015","EFTOTLT_2014","EFTOTLT_2013","Avg_FallEnroll_efatotal_5yrs"]],on=["INSTNM","AWLEVEL"])

# %%
Table_last
# Out:
#                                      INSTNM  AWLEVEL   LATITUDE   LONGITUD  \
# 0                        Miami Dade College        3  25.777717 -80.190856
# 1           Keiser University-Ft Lauderdale        3  26.185869 -80.163959
# 2              Nova Southeastern University        5  26.079337 -80.242480
# 3                           Broward College        3  26.119422 -80.141830
# 4          Florida International University        5  25.757320 -80.373928
# 5                        Miami Dade College        5  25.777717 -80.190856
# 6                 Miami Regional University        3  25.810667 -80.267007
# 7                       University of Miami        5  25.721260 -80.278662
# 8                             SABER College        3  25.771518 -80.261299
# 9                          Barry University        5  25.878908 -80.198925
# 10                          Broward College        5  26.119422 -80.141830
# ...

# %% [markdown]
# ## Admission and Test Score

# %% [markdown]
# ### Applicants total in 2017

# %%
final_df[["INSTNM","APPLCN_2017"]].sort_values(by="APPLCN_2017",ascending=False)
# Out:
#                                      INSTNM  APPLCN_2017
# 10                      University of Miami      30638.0
# 4          Florida International University      19757.0
# 11             Nova Southeastern University       7779.0
# 0                          Barry University       5123.0
# 12                     St Thomas University       2137.0
# 23                Miami Regional University        470.0
# 24                Miami Regional University        470.0
# 3         Concorde Career Institute-Miramar        436.0
# 22                            SABER College        147.0
# 29              West Coast University-Miami         13.0
# 33      Med-Life Institute-Lauderdale Lakes          0.0
# 1                           Broward College          NaN
# 2                           Broward College          NaN
# 5              Florida Career College-Miami          NaN
# 6           Keiser University-Ft Lauderdale          NaN
# ...

# %% [markdown]
# ### Admissions total in 2017

# %%
final_df[["INSTNM","ADMSSN_2017"]].sort_values(by="ADMSSN_2017",ascending=False)
# Out:
#                                      INSTNM  ADMSSN_2017
# 10                      University of Miami      10939.0
# 4          Florida International University      10683.0
# 11             Nova Southeastern University       4525.0
# 0                          Barry University       4358.0
# 12                     St Thomas University       1041.0
# 23                Miami Regional University        396.0
# 24                Miami Regional University        396.0
# 3         Concorde Career Institute-Miramar        327.0
# 22                            SABER College        127.0
# 29              West Coast University-Miami         13.0
# 1                           Broward College          NaN
# 2                           Broward College          NaN
# 5              Florida Career College-Miami          NaN
# 6           Keiser University-Ft Lauderdale          NaN
# 7           Keiser University-Ft Lauderdale          NaN
# ...

# %% [markdown]
# ### Enrolled total in 2017

# %%
final_df[["INSTNM","ENRLT_2017"]].sort_values(by="ENRLT_2017",ascending=False)
# Out:
#                                      INSTNM  ENRLT_2017
# 4          Florida International University      4335.0
# 10                      University of Miami      2212.0
# 11             Nova Southeastern University       987.0
# 0                          Barry University       604.0
# 23                Miami Regional University       396.0
# 24                Miami Regional University       396.0
# 12                     St Thomas University       232.0
# 3         Concorde Career Institute-Miramar       114.0
# 22                            SABER College        75.0
# 29              West Coast University-Miami         7.0
# 1                           Broward College         NaN
# 2                           Broward College         NaN
# 5              Florida Career College-Miami         NaN
# 6           Keiser University-Ft Lauderdale         NaN
# 7           Keiser University-Ft Lauderdale         NaN
# 8                        Miami Dade College         NaN
# ...

# %% [markdown]
# ### Enrolled full time total

# %%
final_df[["INSTNM","ENRLFT_2017"]].sort_values(by="ENRLFT_2017",ascending=False)
# Out:
#                                      INSTNM  ENRLFT_2017
# 4          Florida International University       2512.0
# 10                      University of Miami       2185.0
# 11             Nova Southeastern University        977.0
# 0                          Barry University        604.0
# 12                     St Thomas University        230.0
# 23                Miami Regional University        122.0
# 24                Miami Regional University        122.0
# 3         Concorde Career Institute-Miramar        114.0
# 22                            SABER College         75.0
# 29              West Coast University-Miami          7.0
# 1                           Broward College          NaN
# 2                           Broward College          NaN
# 5              Florida Career College-Miami          NaN
# 6           Keiser University-Ft Lauderdale          NaN
# 7           Keiser University-Ft Lauderdale          NaN
# ...

# %% [markdown]
# ### Enrolled part time total

# %%
final_df[["INSTNM","ENRLPT_2017"]].sort_values(by="ENRLPT_2017",ascending=False)
# Out:
#                                      INSTNM  ENRLPT_2017
# 4          Florida International University       1823.0
# 23                Miami Regional University        274.0
# 24                Miami Regional University        274.0
# 10                      University of Miami         27.0
# 11             Nova Southeastern University         10.0
# 12                     St Thomas University          2.0
# 0                          Barry University          0.0
# 29              West Coast University-Miami          0.0
# 1                           Broward College          NaN
# 2                           Broward College          NaN
# 3         Concorde Career Institute-Miramar          NaN
# 5              Florida Career College-Miami          NaN
# 6           Keiser University-Ft Lauderdale          NaN
# 7           Keiser University-Ft Lauderdale          NaN
# 8                        Miami Dade College          NaN
# ...

# %% [markdown]
# ### Combined Table Admission and Test score

# %% [markdown]
# <b>APPLCN_2017</b>	Applicants total in 2017<br>
# <b>ADMSSN_2017</b>	Admissions total in 2017<br>
# <b>ENRLT_2017</b>	Enrolled total in 2017<br>
# <b>ENRLFT_2017</b>  Enrolled full time total<br>
# <b>ENRLPT_2017</b>  Enrolled part time total<br>

# %% [markdown]
# T6

# %%
final_df[["INSTNM","APPLCN_2017","ADMSSN_2017","ENRLT_2017","ENRLFT_2017","ENRLPT_2017"]]
# Out:
#                                      INSTNM  APPLCN_2017  ADMSSN_2017  \
# 0                          Barry University       5123.0       4358.0
# 1                           Broward College          NaN          NaN
# 2                           Broward College          NaN          NaN
# 3         Concorde Career Institute-Miramar        436.0        327.0
# 4          Florida International University      19757.0      10683.0
# 5              Florida Career College-Miami          NaN          NaN
# 6           Keiser University-Ft Lauderdale          NaN          NaN
# 7           Keiser University-Ft Lauderdale          NaN          NaN
# 8                        Miami Dade College          NaN          NaN
# 9                        Miami Dade College          NaN          NaN
# 10                      University of Miami      30638.0      10939.0
# 11             Nova Southeastern University       7779.0       4525.0
# ...

# %%
Table_last=Table_last.merge(final_df[["INSTNM","AWLEVEL","APPLCN_2017","ADMSSN_2017","ENRLT_2017","ENRLFT_2017","ENRLPT_2017"]],on=["INSTNM","AWLEVEL"])

# %% [markdown]
# ### SAT Math 25th percentile score

# %%
final_df[["INSTNM","SATMT25_2017"]].sort_values(by="SATMT25_2017",ascending=False)
# Out:
#                                      INSTNM  SATMT25_2017
# 10                      University of Miami         610.0
# 4          Florida International University         530.0
# 11             Nova Southeastern University         530.0
# 12                     St Thomas University         440.0
# 0                          Barry University         410.0
# 1                           Broward College           NaN
# 2                           Broward College           NaN
# 3         Concorde Career Institute-Miramar           NaN
# 5              Florida Career College-Miami           NaN
# 6           Keiser University-Ft Lauderdale           NaN
# 7           Keiser University-Ft Lauderdale           NaN
# 8                        Miami Dade College           NaN
# 9                        Miami Dade College           NaN
# 13             City College-Fort Lauderdale           NaN
# 14  Florida National University-Main Campus           NaN
# ...

# %% [markdown]
# ### SAT Math 75th percentile score

# %%
final_df[["INSTNM","SATMT75_2017"]].sort_values(by="SATMT75_2017",ascending=False)
# Out:
#                                      INSTNM  SATMT75_2017
# 10                      University of Miami         720.0
# 11             Nova Southeastern University         640.0
# 4          Florida International University         610.0
# 12                     St Thomas University         560.0
# 0                          Barry University         500.0
# 1                           Broward College           NaN
# 2                           Broward College           NaN
# 3         Concorde Career Institute-Miramar           NaN
# 5              Florida Career College-Miami           NaN
# 6           Keiser University-Ft Lauderdale           NaN
# 7           Keiser University-Ft Lauderdale           NaN
# 8                        Miami Dade College           NaN
# 9                        Miami Dade College           NaN
# 13             City College-Fort Lauderdale           NaN
# 14  Florida National University-Main Campus           NaN
# ...

# %% [markdown]
# ### ACT Math 25th percentile score

# %%
final_df[["INSTNM","ACTMT25_2017"]].sort_values(by="ACTMT25_2017",ascending=False)
# Out:
#                                      INSTNM  ACTMT25_2017
# 10                      University of Miami          26.0
# 11             Nova Southeastern University          22.0
# 4          Florida International University          21.0
# 0                          Barry University          16.0
# 12                     St Thomas University          16.0
# 1                           Broward College           NaN
# 2                           Broward College           NaN
# 3         Concorde Career Institute-Miramar           NaN
# 5              Florida Career College-Miami           NaN
# 6           Keiser University-Ft Lauderdale           NaN
# 7           Keiser University-Ft Lauderdale           NaN
# 8                        Miami Dade College           NaN
# 9                        Miami Dade College           NaN
# 13             City College-Fort Lauderdale           NaN
# 14  Florida National University-Main Campus           NaN
# ...

# %% [markdown]
# ### ACT Math 75th percentile score

# %%
final_df[["ACTMT75 _2017"]]
# Out:
#     ACTMT75 _2017
# 0            20.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4            25.0
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10           32.0
# 11           28.0
# 12           21.0
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
# 30            NaN
# 31            NaN
# 32            NaN
# 33            NaN
# 34            NaN
# 35            NaN

# %%
final_df[["INSTNM","ACTMT75 _2017"]].sort_values(by="ACTMT75 _2017",ascending=False)
# Out:
#                                      INSTNM  ACTMT75 _2017
# 10                      University of Miami           32.0
# 11             Nova Southeastern University           28.0
# 4          Florida International University           25.0
# 12                     St Thomas University           21.0
# 0                          Barry University           20.0
# 1                           Broward College            NaN
# 2                           Broward College            NaN
# 3         Concorde Career Institute-Miramar            NaN
# 5              Florida Career College-Miami            NaN
# 6           Keiser University-Ft Lauderdale            NaN
# 7           Keiser University-Ft Lauderdale            NaN
# 8                        Miami Dade College            NaN
# 9                        Miami Dade College            NaN
# 13             City College-Fort Lauderdale            NaN
# 14  Florida National University-Main Campus            NaN
# ...

# %% [markdown]
# ### Combined Table for SAT and ACT

# %% [markdown]
# <b>ACTMT25_2017</b>  ACT Math 25th percentile score<br>
# <b>SATMT75_2017</b> SAT Math 75th percentile score<br>
# <b>SATMT25_2017</b>  SAT Math 25th percentile score<br>
# <b>ACTMT75 _2017</b> ACT Math 75th percentile score<br>

# %% [markdown]
# T7

# %%
final_df[["INSTNM","ACTMT25_2017","SATMT75_2017","SATMT25_2017","ACTMT75 _2017"]]
# Out:
#                                      INSTNM  ACTMT25_2017  SATMT75_2017  \
# 0                          Barry University          16.0         500.0
# 1                           Broward College           NaN           NaN
# 2                           Broward College           NaN           NaN
# 3         Concorde Career Institute-Miramar           NaN           NaN
# 4          Florida International University          21.0         610.0
# 5              Florida Career College-Miami           NaN           NaN
# 6           Keiser University-Ft Lauderdale           NaN           NaN
# 7           Keiser University-Ft Lauderdale           NaN           NaN
# 8                        Miami Dade College           NaN           NaN
# 9                        Miami Dade College           NaN           NaN
# 10                      University of Miami          26.0         720.0
# 11             Nova Southeastern University          22.0         640.0
# ...

# %%
Table_last=Table_last.merge(final_df[["INSTNM","AWLEVEL","ACTMT25_2017","SATMT75_2017","SATMT25_2017","ACTMT75 _2017"]],on=["INSTNM","AWLEVEL"])

# %%
Table_last
# Out:
#                                      INSTNM  AWLEVEL   LATITUDE   LONGITUD  \
# 0                        Miami Dade College        3  25.777717 -80.190856
# 1           Keiser University-Ft Lauderdale        3  26.185869 -80.163959
# 2              Nova Southeastern University        5  26.079337 -80.242480
# 3                           Broward College        3  26.119422 -80.141830
# 4          Florida International University        5  25.757320 -80.373928
# 5                        Miami Dade College        5  25.777717 -80.190856
# 6                 Miami Regional University        3  25.810667 -80.267007
# 7                       University of Miami        5  25.721260 -80.278662
# 8                             SABER College        3  25.771518 -80.261299
# 9                          Barry University        5  25.878908 -80.198925
# 10                          Broward College        5  26.119422 -80.141830
# ...

# %% [markdown]
# ## Student Financial Aid and Net Price

# %% [markdown]
# #### Student financial aid and net price

# %% [markdown]
# <b>UPGRNTN</b>    Number of undergraduate students awarded Pell grants<br>
# <b>UPGRNTP</b>   Percent of undergraduate students awarded Pell grants><br>
# <b>UPGRNTT</b> Total amount of Pell grant aid awarded to undergraduate students<br>
# <b>UPGRNTA</b> Average amount Pell grant aid awarded to undergraduate students<br>
# <b>UFLOANN</b> Number of undergraduate students awarded federal student loans<br>
# <b>UFLOANP</b> Percent of undergraduate students awarded federal student loans<br>
# <b>UFLOANT</b> Total amount of federal student loans awarded to undergraduate students<br>
# <b>UFLOANA</b> Average amount of federal student loans awarded to undergraduate students<br>

# %% [markdown]
# T8

# %%
final_df[["INSTNM","UPGRNTN_1617","UPGRNTP_1617","UPGRNTT_1617","UPGRNTA_1617","UFLOANN_1617","UFLOANP_1617","UFLOANT_1617","UFLOANA_1617"]]
# Out:
#                                      INSTNM  UPGRNTN_1617  UPGRNTP_1617  \
# 0                          Barry University        1638.0          46.0
# 1                           Broward College       21595.0          49.0
# 2                           Broward College       21595.0          49.0
# 3         Concorde Career Institute-Miramar         616.0          66.0
# 4          Florida International University       22395.0          49.0
# 5              Florida Career College-Miami         480.0          75.0
# 6           Keiser University-Ft Lauderdale       10480.0          61.0
# 7           Keiser University-Ft Lauderdale       10480.0          61.0
# 8                        Miami Dade College       27149.0          49.0
# 9                        Miami Dade College       27149.0          49.0
# 10                      University of Miami        1518.0          14.0
# 11             Nova Southeastern University        1747.0          41.0
# ...

# %%
Table_last=Table_last.merge(final_df[["INSTNM","AWLEVEL","UPGRNTN_1617","UPGRNTP_1617","UPGRNTT_1617","UPGRNTA_1617","UFLOANN_1617","UFLOANP_1617","UFLOANT_1617","UFLOANA_1617"]],on=["INSTNM","AWLEVEL"])

# %%
Table_last
# Out:
#                                      INSTNM  AWLEVEL   LATITUDE   LONGITUD  \
# 0                        Miami Dade College        3  25.777717 -80.190856
# 1           Keiser University-Ft Lauderdale        3  26.185869 -80.163959
# 2              Nova Southeastern University        5  26.079337 -80.242480
# 3                           Broward College        3  26.119422 -80.141830
# 4          Florida International University        5  25.757320 -80.373928
# 5                        Miami Dade College        5  25.777717 -80.190856
# 6                 Miami Regional University        3  25.810667 -80.267007
# 7                       University of Miami        5  25.721260 -80.278662
# 8                             SABER College        3  25.771518 -80.261299
# 9                          Barry University        5  25.878908 -80.198925
# 10                          Broward College        5  26.119422 -80.141830
# ...

# %% [markdown]
# <b>GISTT2</b>   Total amount of grant and scholarship aid awarded, 2016-17 <br>
# <b>GISTA2</b>   Average amount of grant and scholarship aid awarded, 2016-17 <br>
# <b>GISTT1</b> Total amount of grant and scholarship aid awarded, 2015-16<br>
# <b>GISTA1</b> Average amount of grant and scholarship aid awarded, 2015-16<br>
# <b>GISTT0</b> Total amount of grant and scholarship aid awarded, 2014-15<br>
# <b>GISTA0</b> Average amount of grant and scholarship aid awarded, 2014-15<br>

# %% [markdown]
# T9

# %%
final_df[["INSTNM","GISTT2_1617","GISTA2_1617","GISTT1_1617","GISTA1_1617","GISTT0_1617","GISTA0_1617"]]
# Out:
#                                      INSTNM  GISTT2_1617  GISTA2_1617  \
# 0                          Barry University          NaN          NaN
# 1                           Broward College   12872474.0       4881.0
# 2                           Broward College   12872474.0       4881.0
# 3         Concorde Career Institute-Miramar          NaN          NaN
# 4          Florida International University   22087627.0       6667.0
# 5              Florida Career College-Miami          NaN          NaN
# 6           Keiser University-Ft Lauderdale          NaN          NaN
# 7           Keiser University-Ft Lauderdale          NaN          NaN
# 8                        Miami Dade College   31323753.0       5198.0
# 9                        Miami Dade College   31323753.0       5198.0
# 10                      University of Miami          NaN          NaN
# 11             Nova Southeastern University          NaN          NaN
# ...

# %%
Table_last=Table_last.merge(final_df[["INSTNM","AWLEVEL","GISTT2_1617","GISTA2_1617","GISTT1_1617","GISTA1_1617","GISTT0_1617","GISTA0_1617"]],on=["INSTNM","AWLEVEL"])

# %% [markdown]
# <b>GIS4T2</b> Total amount of grant and scholarship aid awarded, all income levels, 2016-17 <br>
# <b>GIS4A2</b> Average amount of grant and scholarship aid awarded, all income levels, 2016-17

# %%
final_df[["INSTNM","GIS4T2_1617","GIS4A2_1617"]]
# Out:
#                                      INSTNM  GIS4T2_1617  GIS4A2_1617
# 0                          Barry University          NaN          NaN
# 1                           Broward College   10832665.0       4212.0
# 2                           Broward College   10832665.0       4212.0
# 3         Concorde Career Institute-Miramar          NaN          NaN
# 4          Florida International University   21169745.0       6552.0
# 5              Florida Career College-Miami          NaN          NaN
# 6           Keiser University-Ft Lauderdale          NaN          NaN
# 7           Keiser University-Ft Lauderdale          NaN          NaN
# 8                        Miami Dade College   28673603.0       5457.0
# 9                        Miami Dade College   28673603.0       5457.0
# 10                      University of Miami          NaN          NaN
# 11             Nova Southeastern University          NaN          NaN
# ...

# %% [markdown]
# <b>GIS4G12</b>    Number awarded grant and scholarship aid, income level (0-30,000), 2016-17<br>
# <b>GIS4T12</b>   Total amount of grant and scholarship aid awarded, income level (0-30,000), 2016-17<br>
# <b>GIS4A12</b>   Average amount of grant and scholarship aid awarded, income level (0-30,000), 2016-17<br>

# %%
final_df[["INSTNM","GIS4G12_1617","GIS4T12_1617","GIS4A12_1617"]]
# Out:
#                                      INSTNM  GIS4G12_1617  GIS4T12_1617  \
# 0                          Barry University           NaN           NaN
# 1                           Broward College        1480.0     7241178.0
# 2                           Broward College        1480.0     7241178.0
# 3         Concorde Career Institute-Miramar           NaN           NaN
# 4          Florida International University        1233.0    11153181.0
# 5              Florida Career College-Miami           NaN           NaN
# 6           Keiser University-Ft Lauderdale           NaN           NaN
# 7           Keiser University-Ft Lauderdale           NaN           NaN
# 8                        Miami Dade College        3891.0    22440168.0
# 9                        Miami Dade College        3891.0    22440168.0
# 10                      University of Miami           NaN           NaN
# 11             Nova Southeastern University           NaN           NaN
# ...

# %% [markdown]
# <b>GIS4N22</b>   Number in income level (30,001-48,000), 2016-17<br>
# <b>GIS4G22</b>    Number awarded grant and scholarship aid, income level (30,001-48,000), 2016-17<br>
# <b>GIS4T22</b>   Total amount of grant and scholarship aid awarded, income level (30,001-48,000), 2016-17<br>
# <b>GIS4A22</b>   Average amount of grant and scholarship aid awarded, income level (30,001-48,000), 2016-17<br>

# %%
final_df[["INSTNM","GIS4N22_1617","GIS4G22_1617","GIS4T22_1617","GIS4A22_1617"]]
# Out:
#                                      INSTNM  GIS4N22_1617  GIS4G22_1617  \
# 0                          Barry University           NaN           NaN
# 1                           Broward College         583.0         572.0
# 2                           Broward College         583.0         572.0
# 3         Concorde Career Institute-Miramar           NaN           NaN
# 4          Florida International University         497.0         496.0
# 5              Florida Career College-Miami           NaN           NaN
# 6           Keiser University-Ft Lauderdale           NaN           NaN
# 7           Keiser University-Ft Lauderdale           NaN           NaN
# 8                        Miami Dade College         970.0         967.0
# 9                        Miami Dade College         970.0         967.0
# 10                      University of Miami           NaN           NaN
# 11             Nova Southeastern University           NaN           NaN
# ...

# %% [markdown]
# <b>GIS4N32</b>   Number in income level (48,001-75,000), 2016-17<br>
# <b>GIS4G32</b>   Number awarded grant and scholarship aid, income level (48,001-75,000), 2016-17<br>
# <b>GIS4T32</b>   Total amount of grant and scholarship aid awarded, income level (48,001-75,000), 2016-17<br>
# <b>GIS4A32</b>   Average amount of grant and scholarship aid awarded, income level (48,001-75,000), 2016-17<br>

# %%
final_df[["INSTNM","GIS4N32_1617","GIS4G32_1617","GIS4T32_1617","GIS4A32_1617"]]
# Out:
#                                      INSTNM  GIS4N32_1617  GIS4G32_1617  \
# 0                          Barry University           NaN           NaN
# 1                           Broward College         354.0         317.0
# 2                           Broward College         354.0         317.0
# 3         Concorde Career Institute-Miramar           NaN           NaN
# 4          Florida International University         459.0         454.0
# 5              Florida Career College-Miami           NaN           NaN
# 6           Keiser University-Ft Lauderdale           NaN           NaN
# 7           Keiser University-Ft Lauderdale           NaN           NaN
# 8                        Miami Dade College         330.0         326.0
# 9                        Miami Dade College         330.0         326.0
# 10                      University of Miami           NaN           NaN
# 11             Nova Southeastern University           NaN           NaN
# ...

# %% [markdown]
# <b>GIS4N42</b>   Number in income level (75,001-110,000), 2016-17<br>
# <b>GIS4G42</b>   Number awarded grant and scholarship aid, income level (75,001-110,000), 2016-17<br>
# <b>GIS4T42</b>   Total amount of grant and scholarship aid awarded, income level (75,001-110,000), 2016-17<br>
# <b>GIS4A42</b>   Average amount of grant and scholarship aid awarded, income level (75,001-110,000), 2016-17<br>

# %%
final_df[["INSTNM","GIS4N42_1617","GIS4G42_1617","GIS4T42_1617","GIS4A42_1617"]]
# Out:
#                                      INSTNM  GIS4N42_1617  GIS4G42_1617  \
# 0                          Barry University           NaN           NaN
# 1                           Broward College         104.0          36.0
# 2                           Broward College         104.0          36.0
# 3         Concorde Career Institute-Miramar           NaN           NaN
# 4          Florida International University         418.0         380.0
# 5              Florida Career College-Miami           NaN           NaN
# 6           Keiser University-Ft Lauderdale           NaN           NaN
# 7           Keiser University-Ft Lauderdale           NaN           NaN
# 8                        Miami Dade College          43.0          28.0
# 9                        Miami Dade College          43.0          28.0
# 10                      University of Miami           NaN           NaN
# 11             Nova Southeastern University           NaN           NaN
# ...

# %% [markdown]
# <b>GIS4N52</b>   Number in income level (110,001 or more), 2016-17<br>
# <b>GIS4G52</b>   Number awarded grant and scholarship aid, income level (110,001 or more), 2016-17<br>
# <b>GIS4T52</b>   Total amount of grant and scholarship aid awarded, income level (110,001 or more), 2016-17<br>
# <b>GIS4A52</b>   Average amount of grant and scholarship aid awarded, income level (110,001 or more), 2016-17<br>

# %%
final_df[["INSTNM","GIS4N52_1617","GIS4G52_1617","GIS4T52_1617","GIS4A52_1617"]]
# Out:
#                                      INSTNM  GIS4N52_1617  GIS4G52_1617  \
# 0                          Barry University           NaN           NaN
# 1                           Broward College          43.0           9.0
# 2                           Broward College          43.0           9.0
# 3         Concorde Career Institute-Miramar           NaN           NaN
# 4          Florida International University         622.0         436.0
# 5              Florida Career College-Miami           NaN           NaN
# 6           Keiser University-Ft Lauderdale           NaN           NaN
# 7           Keiser University-Ft Lauderdale           NaN           NaN
# 8                        Miami Dade College          17.0           2.0
# 9                        Miami Dade College          17.0           2.0
# 10                      University of Miami           NaN           NaN
# 11             Nova Southeastern University           NaN           NaN
# ...

# %% [markdown]
# ## Combined table

# %% [markdown]
# <b>GIS4T2</b> Total amount of grant and scholarship aid awarded, all income levels, 2016-17 <br>
# <b>GIS4A2</b> Average amount of grant and scholarship aid awarded, all income levels, 2016-17<br>
# <b>GIS4G12</b>    Number awarded grant and scholarship aid, income level (0-30,000), 2016-17<br>
# <b>GIS4T12</b>   Total amount of grant and scholarship aid awarded, income level (0-30,000), 2016-17<br>
# <b>GIS4A12</b>   Average amount of grant and scholarship aid awarded, income level (0-30,000), 2016-17<br>
# <b>GIS4N22</b>   Number in income level (30,001-48,000), 2016-17<br>
# <b>GIS4G22</b>    Number awarded grant and scholarship aid, income level (30,001-48,000), 2016-17<br>
# <b>GIS4T22</b>   Total amount of grant and scholarship aid awarded, income level (30,001-48,000), 2016-17<br>
# <b>GIS4A22</b>   Average amount of grant and scholarship aid awarded, income level (30,001-48,000), 2016-17<br>
# <b>GIS4N32</b>   Number in income level (48,001-75,000), 2016-17<br>
# <b>GIS4G32</b>   Number awarded grant and scholarship aid, income level (48,001-75,000), 2016-17<br>
# <b>GIS4T32</b>   Total amount of grant and scholarship aid awarded, income level (48,001-75,000), 2016-17<br>
# <b>GIS4A32</b>   Average amount of grant and scholarship aid awarded, income level (48,001-75,000), 2016-17<br>
# <b>GIS4N42</b>   Number in income level (75,001-110,000), 2016-17<br>
# <b>GIS4G42</b>   Number awarded grant and scholarship aid, income level (75,001-110,000), 2016-17<br>
# <b>GIS4T42</b>   Total amount of grant and scholarship aid awarded, income level (75,001-110,000), 2016-17<br>
# <b>GIS4A42</b>   Average amount of grant and scholarship aid awarded, income level (75,001-110,000), 2016-17<br>
# <b>GIS4N52</b>   Number in income level (110,001 or more), 2016-17<br>
# <b>GIS4G52</b>   Number awarded grant and scholarship aid, income level (110,001 or more), 2016-17<br>
# <b>GIS4T52</b>   Total amount of grant and scholarship aid awarded, income level (110,001 or more), 2016-17<br>
# <b>GIS4A52</b>   Average amount of grant and scholarship aid awarded, income level (110,001 or more), 2016-17<br>

# %% [markdown]
# T10

# %%
Table_last=Table_last.merge(final_df[["INSTNM","AWLEVEL","GIS4T2_1617","GIS4A2_1617","GIS4N22_1617","GIS4G22_1617","GIS4T22_1617","GIS4A22_1617","GIS4N32_1617","GIS4G32_1617","GIS4T32_1617","GIS4A32_1617","GIS4N42_1617","GIS4G42_1617","GIS4T42_1617","GIS4A42_1617"]],on=["INSTNM","AWLEVEL"])

# %%
final_df[["INSTNM","GIS4T2_1617","GIS4A2_1617","GIS4N22_1617","GIS4G22_1617","GIS4T22_1617","GIS4A22_1617","GIS4N32_1617","GIS4G32_1617","GIS4T32_1617","GIS4A32_1617","GIS4N42_1617","GIS4G42_1617","GIS4T42_1617","GIS4A42_1617"]]
# Out:
#                                      INSTNM  GIS4T2_1617  GIS4A2_1617  \
# 0                          Barry University          NaN          NaN
# 1                           Broward College   10832665.0       4212.0
# 2                           Broward College   10832665.0       4212.0
# 3         Concorde Career Institute-Miramar          NaN          NaN
# 4          Florida International University   21169745.0       6552.0
# 5              Florida Career College-Miami          NaN          NaN
# 6           Keiser University-Ft Lauderdale          NaN          NaN
# 7           Keiser University-Ft Lauderdale          NaN          NaN
# 8                        Miami Dade College   28673603.0       5457.0
# 9                        Miami Dade College   28673603.0       5457.0
# 10                      University of Miami          NaN          NaN
# 11             Nova Southeastern University          NaN          NaN
# ...

# %%
Table_last
# Out:
#                                      INSTNM  AWLEVEL   LATITUDE   LONGITUD  \
# 0                        Miami Dade College        3  25.777717 -80.190856
# 1           Keiser University-Ft Lauderdale        3  26.185869 -80.163959
# 2              Nova Southeastern University        5  26.079337 -80.242480
# 3                           Broward College        3  26.119422 -80.141830
# 4          Florida International University        5  25.757320 -80.373928
# 5                        Miami Dade College        5  25.777717 -80.190856
# 6                 Miami Regional University        3  25.810667 -80.267007
# 7                       University of Miami        5  25.721260 -80.278662
# 8                             SABER College        3  25.771518 -80.261299
# 9                          Barry University        5  25.878908 -80.198925
# 10                          Broward College        5  26.119422 -80.141830
# ...

# %% [markdown]
# <b>NPGRN2</b> Average net price-students awarded grant or scholarship aid, 2016-17<br>
# <b>NPGRN1</b> Average net price-students awarded grant or scholarship aid, 2015-16<br>
# <b>NPGRN0</b> Average net price-students awarded grant or scholarship aid, 2014-15<br>
# <b>NPT412</b> Average net price (income 0-30,000)-students awarded Title IV federal financial aid, 2016-17<br>
# <b>NPT422</b> Average net price (income 30,001-48,000)-students awarded Title IV federal financial aid, 2016-17<br>
# <b>NPT432</b> Average net price (income 48,001-75,000)-students awarded Title IV federal financial aid, 2016-17<br>
# <b>NPT442</b> Average net price (income 75,001-110,000)-students awarded Title IV federal financial aid, 2016-17<br>
# <b>NPT455</b> Average net price (income over 110,000)-students awarded Title IV federal financial aid, 2016-17<br>

# %%
final_df[["INSTNM","NPGRN2_1617","NPGRN1_1617","NPGRN0_1617","NPT412_1617","NPT422_1617","NPT432_1617","NPT442_1617","NPT452_1617"]]
# Out:
#                                      INSTNM  NPGRN2_1617  NPGRN1_1617  \
# 0                          Barry University      21547.0      21489.0
# 1                           Broward College          NaN          NaN
# 2                           Broward College          NaN          NaN
# 3         Concorde Career Institute-Miramar      26953.0      23620.0
# 4          Florida International University          NaN          NaN
# 5              Florida Career College-Miami      30757.0      31886.0
# 6           Keiser University-Ft Lauderdale      26730.0      27516.0
# 7           Keiser University-Ft Lauderdale      26730.0      27516.0
# 8                        Miami Dade College          NaN          NaN
# 9                        Miami Dade College          NaN          NaN
# 10                      University of Miami      42204.0      37424.0
# 11             Nova Southeastern University      26740.0      25344.0
# ...

# %% [markdown]
# <b>NPT411</b> Average net price (income 0-30,000)-students awarded Title IV federal financial aid, 2015-16<br>
# <b>NPT421</b> Average net price (income 30,001-48,000)-students awarded Title IV federal financial aid, 2015-16<br>
# <b>NPT431</b> Average net price (income 48,001-75,000)-students awarded Title IV federal financial aid, 2015-16<br>
# <b>NPT441</b> Average net price (income 75,001-110,000)-students awarded Title IV federal financial aid, 2015-16<br>
# <b>NPT451</b> Average net price (income over 110,000)-students awarded Title IV federal financial aid, 2015-16<br>

# %%
final_df[["INSTNM","NPT411_1617","NPT421_1617","NPT431_1617","NPT441_1617","NPT451_1617"]]
# Out:
#                                      INSTNM  NPT411_1617  NPT421_1617  \
# 0                          Barry University      17981.0      17255.0
# 1                           Broward College          NaN          NaN
# 2                           Broward College          NaN          NaN
# 3         Concorde Career Institute-Miramar      25674.0      27824.0
# 4          Florida International University          NaN          NaN
# 5              Florida Career College-Miami      31950.0      32277.0
# 6           Keiser University-Ft Lauderdale      27386.0      28025.0
# 7           Keiser University-Ft Lauderdale      27386.0      28025.0
# 8                        Miami Dade College          NaN          NaN
# 9                        Miami Dade College          NaN          NaN
# 10                      University of Miami      26911.0      18903.0
# 11             Nova Southeastern University      22993.0      22271.0
# ...

# %% [markdown]
# <b>NPT410</b> Average net price (income 0-30,000)-students awarded Title IV federal financial aid, 2014-15<br>
# <b>NPT420</b> Average net price (income 30,001-48,000)-students awarded Title IV federal financial aid, 2014-15<br>
# <b>NPT430</b> Average net price (income 48,001-75,000)-students awarded Title IV federal financial aid, 2014-15<br>
# <b>NPT440</b> Average net price (income 75,001-110,000)-students awarded Title IV federal financial aid, 2014-15<br>
# <b>NPT450</b> Average net price (income over 110,000)-students awarded Title IV federal financial aid, 2014-15<br>

# %%
final_df[["INSTNM","NPT410_1617","NPT420_1617","NPT430_1617","NPT440_1617","NPT450  _1617"]]
# Out:
#                                      INSTNM  NPT410_1617  NPT420_1617  \
# 0                          Barry University      22047.0      21820.0
# 1                           Broward College          NaN          NaN
# 2                           Broward College          NaN          NaN
# 3         Concorde Career Institute-Miramar      24669.0      28826.0
# 4          Florida International University          NaN          NaN
# 5              Florida Career College-Miami      41450.0      41497.0
# 6           Keiser University-Ft Lauderdale      28372.0      28893.0
# 7           Keiser University-Ft Lauderdale      28372.0      28893.0
# 8                        Miami Dade College          NaN          NaN
# 9                        Miami Dade College          NaN          NaN
# 10                      University of Miami      25202.0      24745.0
# 11             Nova Southeastern University      21083.0      22580.0
# ...

# %% [markdown]
# ## Combined Table for Average net price students awarded Title IV federal financial aid

# %% [markdown]
# <b>NPGRN2</b> Average net price-students awarded grant or scholarship aid, 2016-17<br>
# <b>NPGRN1</b> Average net price-students awarded grant or scholarship aid, 2015-16<br>
# <b>NPGRN0</b> Average net price-students awarded grant or scholarship aid, 2014-15<br>
# <b>NPT412</b> Average net price (income 0-30,000)-students awarded Title IV federal financial aid, 2016-17<br>
# <b>NPT422</b> Average net price (income 30,001-48,000)-students awarded Title IV federal financial aid, 2016-17<br>
# <b>NPT432</b> Average net price (income 48,001-75,000)-students awarded Title IV federal financial aid, 2016-17<br>
# <b>NPT442</b> Average net price (income 75,001-110,000)-students awarded Title IV federal financial aid, 2016-17<br>
# <b>NPT455</b> Average net price (income over 110,000)-students awarded Title IV federal financial aid, 2016-17<br>
# <b>NPT411</b> Average net price (income 0-30,000)-students awarded Title IV federal financial aid, 2015-16<br>
# <b>NPT421</b> Average net price (income 30,001-48,000)-students awarded Title IV federal financial aid, 2015-16<br>
# <b>NPT431</b> Average net price (income 48,001-75,000)-students awarded Title IV federal financial aid, 2015-16<br>
# <b>NPT441</b> Average net price (income 75,001-110,000)-students awarded Title IV federal financial aid, 2015-16<br>
# <b>NPT451</b> Average net price (income over 110,000)-students awarded Title IV federal financial aid, 2015-16<br>
# <b>NPT410</b> Average net price (income 0-30,000)-students awarded Title IV federal financial aid, 2014-15<br>
# <b>NPT420</b> Average net price (income 30,001-48,000)-students awarded Title IV federal financial aid, 2014-15<br>
# <b>NPT430</b> Average net price (income 48,001-75,000)-students awarded Title IV federal financial aid, 2014-15<br>
# <b>NPT440</b> Average net price (income 75,001-110,000)-students awarded Title IV federal financial aid, 2014-15<br>
# <b>NPT450</b> Average net price (income over 110,000)-students awarded Title IV federal financial aid, 2014-15<br>

# %%
final_df[["INSTNM","NPGRN2_1617","NPGRN1_1617","NPGRN0_1617","NPT412_1617","NPT422_1617","NPT432_1617","NPT442_1617","NPT452_1617","NPT411_1617","NPT421_1617","NPT431_1617","NPT441_1617","NPT451_1617","NPT410_1617","NPT420_1617","NPT430_1617","NPT440_1617","NPT450  _1617"]]
# Out:
#                                      INSTNM  NPGRN2_1617  NPGRN1_1617  \
# 0                          Barry University      21547.0      21489.0
# 1                           Broward College          NaN          NaN
# 2                           Broward College          NaN          NaN
# 3         Concorde Career Institute-Miramar      26953.0      23620.0
# 4          Florida International University          NaN          NaN
# 5              Florida Career College-Miami      30757.0      31886.0
# 6           Keiser University-Ft Lauderdale      26730.0      27516.0
# 7           Keiser University-Ft Lauderdale      26730.0      27516.0
# 8                        Miami Dade College          NaN          NaN
# 9                        Miami Dade College          NaN          NaN
# 10                      University of Miami      42204.0      37424.0
# 11             Nova Southeastern University      26740.0      25344.0
# ...

# %%
Table_last=Table_last.merge(final_df[["INSTNM","AWLEVEL","NPGRN2_1617","NPGRN1_1617","NPGRN0_1617","NPT412_1617","NPT422_1617","NPT432_1617","NPT442_1617","NPT452_1617","NPT411_1617","NPT421_1617","NPT431_1617","NPT441_1617","NPT451_1617","NPT410_1617","NPT420_1617","NPT430_1617","NPT440_1617","NPT450  _1617"]],on=["INSTNM","AWLEVEL"])

# %%
Table_last
# Out:
#                                      INSTNM  AWLEVEL   LATITUDE   LONGITUD  \
# 0                        Miami Dade College        3  25.777717 -80.190856
# 1           Keiser University-Ft Lauderdale        3  26.185869 -80.163959
# 2              Nova Southeastern University        5  26.079337 -80.242480
# 3                           Broward College        3  26.119422 -80.141830
# 4          Florida International University        5  25.757320 -80.373928
# 5                        Miami Dade College        5  25.777717 -80.190856
# 6                 Miami Regional University        3  25.810667 -80.267007
# 7                       University of Miami        5  25.721260 -80.278662
# 8                             SABER College        3  25.771518 -80.261299
# 9                          Barry University        5  25.878908 -80.198925
# 10                          Broward College        5  26.119422 -80.141830
# ...

# %%
Table_last.to_csv(path_to_processed_data+"AnalysisAndFindings_485272_rerun.csv",index=False)
